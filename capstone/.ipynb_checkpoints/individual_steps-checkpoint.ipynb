# %%
# %%sh
#
# pip3 install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting dvc==2.8.3
#   Downloading dvc-2.8.3-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 12.0 MB/s eta 0:00:00
# Collecting s3fs==2021.11.0
#   Downloading s3fs-2021.11.0-py3-none-any.whl (25 kB)
# Collecting git-remote-codecommit==1.16
#   Downloading git-remote-codecommit-1.16.tar.gz (7.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting sagemaker-experiments==0.1.42
#   Using cached sagemaker_experiments-0.1.42-py3-none-any.whl (42 kB)
# Collecting gitpython==3.1.29
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 2.7 MB/s eta 0:00:00
# Collecting pytorch-lightning==1.8.5.post0
#   Downloading pytorch_lightning-1.8.5.post0-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: timm==0.6.12 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (0.6.12)
# Requirement already satisfied: ipykernel==6.16.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r requirements.txt (line 9)) (6.16.2)
# Requirement already satisfied: scikit-learn==1.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (1.0.2)
# Collecting albumentations==1.3.0
#   Downloading albumentations-1.3.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (2.28.1)
# Collecting rich>=10.13.0
#   Downloading rich-13.2.0-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: distro>=1.3.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (1.8.0)
# Collecting pygtrie>=2.3.2
#   Downloading pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: packaging>=19.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (21.3)
# Collecting ruamel.yaml>=0.17.11
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 31.0 MB/s eta 0:00:00
# Collecting aiohttp-retry>=2.4.5
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Collecting configobj>=5.0.6
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: toml>=0.10.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (0.10.2)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: fsspec[http]>=2021.10.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (2022.10.0)
# Collecting voluptuous>=0.11.7
#   Downloading voluptuous-0.13.1-py3-none-any.whl (29 kB)
# Collecting zc.lockfile>=1.2.1
#   Downloading zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (4.4.0)
# Collecting shtab<2,>=1.3.4
#   Downloading shtab-1.5.8-py2.py3-none-any.whl (13 kB)
# Collecting pydot>=1.2.4
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: tqdm<5,>=4.45.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (4.64.1)
# Collecting networkx>=2.5
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.0 MB/s eta 0:00:00
# Collecting appdirs>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting ply>=3.9
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.2 MB/s eta 0:00:00
# Collecting funcy>=1.14
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: importlib-resources>=5.2.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (5.10.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (4.11.4)
# Requirement already satisfied: colorama>=0.3.9 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: psutil>=5.8.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (5.9.3)
# Collecting nanotime>=0.5.2
#   Downloading nanotime-0.5.2.tar.gz (3.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dulwich>=0.20.23
#   Downloading dulwich-0.21.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (504 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 504.4/504.4 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1>=0.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (0.4.8)
# Collecting dictdiffer>=0.8.1
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Collecting python-benedict>=0.24.2
#   Downloading python_benedict-0.28.3-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 12.2 MB/s eta 0:00:00
# Collecting grandalf==0.6
#   Downloading grandalf-0.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dvc==2.8.3->-r requirements.txt (line 1)) (3.0.9)
# Collecting flufl.lock>=5
#   Downloading flufl.lock-7.1.1-py3-none-any.whl (11 kB)
# Collecting diskcache>=5.2.1
#   Downloading diskcache-5.4.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 12.3 MB/s eta 0:00:00
# Collecting pygit2>=1.5.0
#   Downloading pygit2-1.10.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 7.5 MB/s eta 0:00:00
# Collecting tabulate>=0.8.7
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting flatten-dict<1,>=0.4.1
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Collecting dpath<3,>=2.0.2
#   Downloading dpath-2.1.4-py3-none-any.whl (17 kB)
# Collecting pathspec<0.10.0,>=0.9.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting aiobotocore~=1.4.1
#   Downloading aiobotocore-1.4.2.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 15.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting fsspec==2021.11.0
#   Downloading fsspec-2021.11.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.4/132.4 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp>=3.7.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from s3fs==2021.11.0->-r requirements.txt (line 2)) (3.8.3)
# Collecting aiobotocore[boto3]>1.0.1
#   Downloading aiobotocore-2.4.2-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: botocore>=1.17.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from git-remote-codecommit==1.16->-r requirements.txt (line 4)) (1.29.44)
# Requirement already satisfied: boto3>=1.16.27 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sagemaker-experiments==0.1.42->-r requirements.txt (line 5)) (1.26.44)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (5.4.1)
# Requirement already satisfied: numpy>=1.17.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (1.21.6)
# Requirement already satisfied: torch>=1.9.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (1.13.1)
# Requirement already satisfied: lightning-utilities!=0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (0.6.0.post0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: huggingface-hub in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from timm==0.6.12->-r requirements.txt (line 8)) (0.10.1)
# Requirement already satisfied: torchvision in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from timm==0.6.12->-r requirements.txt (line 8)) (0.14.1)
# Requirement already satisfied: traitlets>=5.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (5.5.0)
# Requirement already satisfied: nest-asyncio in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (7.4.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (6.2)
# Requirement already satisfied: ipython>=7.23.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (7.33.0)
# Requirement already satisfied: debugpy>=1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipykernel==6.16.2->-r requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: scipy>=1.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 10)) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from scikit-learn==1.0.2->-r requirements.txt (line 10)) (3.1.0)
# Collecting qudida>=0.0.4
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python-headless>=4.1.1
#   Downloading opencv_python_headless-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 MB 35.1 MB/s eta 0:00:00
# Collecting scikit-image>=0.16.1
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 79.8 MB/s eta 0:00:00
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from grandalf==0.6->dvc==2.8.3->-r requirements.txt (line 1)) (0.18.2)
# Collecting botocore>=1.17.0
#   Downloading botocore-1.20.106-py2.py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 28.4 MB/s eta 0:00:00
# Collecting wrapt>=1.10.10
#   Downloading wrapt-1.14.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 16.2 MB/s eta 0:00:00
# Collecting aioitertools>=0.5.1
#   Using cached aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Collecting aiobotocore[boto3]>1.0.1
#   Downloading aiobotocore-2.4.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 571.4 kB/s eta 0:00:00
#   Downloading aiobotocore-2.4.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 11.9 MB/s eta 0:00:00
#   Downloading aiobotocore-2.3.4-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.5 MB/s eta 0:00:00
#   Downloading aiobotocore-2.3.3.tar.gz (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.3.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 23.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.3.1.tar.gz (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.3.0.tar.gz (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 kB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.2.0.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.1.2.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 832.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.1.1.tar.gz (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.1.0.tar.gz (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Using cached aiobotocore-2.0.1.tar.gz (54 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading aiobotocore-2.0.0.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting boto3>=1.16.27
#   Downloading boto3-1.17.106-py2.py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (20.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from aiohttp>=3.7.1->s3fs==2021.11.0->-r requirements.txt (line 2)) (4.0.2)
# Collecting s3transfer<0.5.0,>=0.4.0
#   Downloading s3transfer-0.4.2-py2.py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.2/79.2 kB 7.1 MB/s eta 0:00:00
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore>=1.17.0->git-remote-codecommit==1.16->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore>=1.17.0->git-remote-codecommit==1.16->-r requirements.txt (line 4)) (1.26.8)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from configobj>=5.0.6->dvc==2.8.3->-r requirements.txt (line 1)) (1.16.0)
# Collecting atpublic>=2.3
#   Downloading atpublic-3.1.1-py3-none-any.whl (4.8 kB)
# Collecting fsspec[http]>=2021.10.1
#   Downloading fsspec-2023.1.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 24.7 MB/s eta 0:00:00
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 23.9 MB/s eta 0:00:00
#   Downloading fsspec-2022.8.2-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.8/140.8 kB 28.5 MB/s eta 0:00:00
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 1.7 MB/s eta 0:00:00
#   Downloading fsspec-2022.7.0-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 2.6 MB/s eta 0:00:00
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 4.6 MB/s eta 0:00:00
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.1/136.1 kB 2.4 MB/s eta 0:00:00
#   Downloading fsspec-2022.2.0-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 34.7 MB/s eta 0:00:00
#   Downloading fsspec-2022.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 35.3 MB/s eta 0:00:00
#   Using cached fsspec-2021.11.1-py3-none-any.whl (132 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from importlib-metadata>=1.4->dvc==2.8.3->-r requirements.txt (line 1)) (3.10.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (3.0.31)
# Requirement already satisfied: backcall in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: pickleshare in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: pygments in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (2.13.0)
# Requirement already satisfied: pexpect>4.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (65.5.0)
# Requirement already satisfied: entrypoints in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel==6.16.2->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel==6.16.2->-r requirements.txt (line 9)) (4.11.1)
# Requirement already satisfied: cached-property in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pygit2>=1.5.0->dvc==2.8.3->-r requirements.txt (line 1)) (1.5.2)
# Requirement already satisfied: cffi>=1.9.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pygit2>=1.5.0->dvc==2.8.3->-r requirements.txt (line 1)) (1.15.1)
# Collecting python-fsutil<1.0.0,>=0.9.3
#   Downloading python_fsutil-0.9.3-py3-none-any.whl (13 kB)
# Collecting phonenumbers<9.0.0,>=8.12.0
#   Downloading phonenumbers-8.13.4-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 34.5 MB/s eta 0:00:00
# Collecting mailchecker<6.0.0,>=4.1.0
#   Downloading mailchecker-5.0.7.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 19.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python-slugify<8.0.0,>=6.0.1
#   Downloading python_slugify-7.0.0-py2.py3-none-any.whl (9.4 kB)
# Collecting xlrd<3.0.0,>=2.0.0
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 1.8 MB/s eta 0:00:00
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 27.3 MB/s eta 0:00:00
# Collecting python-benedict>=0.24.2
#   Downloading python_benedict-0.28.2-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.0/122.0 kB 2.3 MB/s eta 0:00:00
#   Downloading python_benedict-0.28.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 2.5 MB/s eta 0:00:00
#   Downloading python_benedict-0.28.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 12.5 MB/s eta 0:00:00
#   Downloading python_benedict-0.27.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 12.2 MB/s eta 0:00:00
#   Downloading python_benedict-0.27.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 7.1 MB/s eta 0:00:00
# Collecting python-slugify<7.0.0,>=6.0.1
#   Downloading python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
# Collecting python-benedict>=0.24.2
#   Downloading python_benedict-0.26.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 9.9 MB/s eta 0:00:00
# Collecting openpyxl<4.0.0,>=3.0.0
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 49.7 MB/s eta 0:00:00
# Collecting ftfy<7.0.0,>=6.0.0
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 13.2 MB/s eta 0:00:00
# Collecting xmltodict<1.0.0,>=0.12.0
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.22.0->dvc==2.8.3->-r requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.22.0->dvc==2.8.3->-r requirements.txt (line 1)) (3.4)
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 24.2 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (500 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.1/500.1 kB 4.7 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 52.3 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0->-r requirements.txt (line 11)) (2.22.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from scikit-image>=0.16.1->albumentations==1.3.0->-r requirements.txt (line 11)) (9.3.0)
# Collecting protobuf<=3.20.1,>=3.8.0
#   Downloading protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.9.0->pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (11.7.99)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.9.0->pytorch-lightning==1.8.5.post0->-r requirements.txt (line 7)) (0.37.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from huggingface-hub->timm==0.6.12->-r requirements.txt (line 8)) (3.8.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from cffi>=1.9.1->pygit2>=1.5.0->dvc==2.8.3->-r requirements.txt (line 1)) (2.21)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ftfy<7.0.0,>=6.0.0->python-benedict>=0.24.2->dvc==2.8.3->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (0.8.3)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.16.2->-r requirements.txt (line 9)) (0.7.0)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 12.1 MB/s eta 0:00:00
# Building wheels for collected packages: git-remote-codecommit, aiobotocore, nanotime, mailchecker
#   Building wheel for git-remote-codecommit (setup.py): started
#   Building wheel for git-remote-codecommit (setup.py): finished with status 'done'
#   Created wheel for git-remote-codecommit: filename=git_remote_codecommit-1.16-py3-none-any.whl size=7112 sha256=3db5254f24ad8597e7c7ccf8ba295dfcf3866f370dbdfad8964894da45fae511
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/14/c6/63/7d7aa2a4fae9375680b5a691166b3faa324d51ff2366d99e40
#   Building wheel for aiobotocore (setup.py): started
#   Building wheel for aiobotocore (setup.py): finished with status 'done'
#   Created wheel for aiobotocore: filename=aiobotocore-1.4.2-py3-none-any.whl size=49908 sha256=eb6ec032c4d509f7c019f944a44f2bb442de032c3d5f79237612d69b101c001e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/b5/7f/c0/c519b96564f998197691cd74c5db8ce8f39650e90b6aa66c60
#   Building wheel for nanotime (setup.py): started
#   Building wheel for nanotime (setup.py): finished with status 'done'
#   Created wheel for nanotime: filename=nanotime-0.5.2-py3-none-any.whl size=2425 sha256=33eeaa8dc5287b9b1173813c5edfa9fd24465ef2c2a7bf64c7c63f1418ffe367
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/59/8c/0f/2660400ed4bea15ff3044b20cd7ba6322db2e65c1912659757
#   Building wheel for mailchecker (setup.py): started
#   Building wheel for mailchecker (setup.py): finished with status 'done'
#   Created wheel for mailchecker: filename=mailchecker-5.0.7-py3-none-any.whl size=322214 sha256=2da8ef6f510d96c50e0bfa732eda0677ba77eb80bb0648048789adc0df02013c
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/98/b2/b1/fc3b58737c76c195cf8dbf0ddc00ac038734d9b37ad9d540c5
# Successfully built git-remote-codecommit aiobotocore nanotime mailchecker
# Installing collected packages: voluptuous, text-unidecode, python-fsutil, pygtrie, ply, phonenumbers, nanotime, mailchecker, funcy, dictdiffer, appdirs, zc.lockfile, xmltodict, xlrd, wrapt, tifffile, tabulate, smmap, shtab, shortuuid, ruamel.yaml.clib, PyYAML, PyWavelets, python-slugify, pydot, protobuf, pathspec, opencv-python-headless, networkx, mdurl, jmespath, grandalf, ftfy, fsspec, et-xmlfile, dulwich, dpath, diskcache, configobj, atpublic, aioitertools, tensorboardX, scikit-image, ruamel.yaml, pygit2, openpyxl, markdown-it-py, gitdb, flufl.lock, flatten-dict, botocore, s3transfer, rich, qudida, python-benedict, gitpython, git-remote-codecommit, aiohttp-retry, aiobotocore, s3fs, dvc, boto3, albumentations, sagemaker-experiments, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.4.1
#     Uninstalling PyYAML-5.4.1:
#       Successfully uninstalled PyYAML-5.4.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.10.0
#     Uninstalling fsspec-2022.10.0:
#       Successfully uninstalled fsspec-2022.10.0
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.44
#     Uninstalling botocore-1.29.44:
#       Successfully uninstalled botocore-1.29.44
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.6.0
#     Uninstalling s3transfer-0.6.0:
#       Successfully uninstalled s3transfer-0.6.0
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.26.44
#     Uninstalling boto3-1.26.44:
#       Successfully uninstalled boto3-1.26.44
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 1.9.0
#     Uninstalling pytorch-lightning-1.9.0:
#       Successfully uninstalled pytorch-lightning-1.9.0
# Successfully installed PyWavelets-1.3.0 PyYAML-6.0 aiobotocore-1.4.2 aiohttp-retry-2.8.3 aioitertools-0.11.0 albumentations-1.3.0 appdirs-1.4.4 atpublic-3.1.1 boto3-1.17.106 botocore-1.20.106 configobj-5.0.8 dictdiffer-0.9.0 diskcache-5.4.0 dpath-2.1.4 dulwich-0.21.2 dvc-2.8.3 et-xmlfile-1.1.0 flatten-dict-0.4.2 flufl.lock-7.1.1 fsspec-2021.11.0 ftfy-6.1.1 funcy-1.17 git-remote-codecommit-1.16 gitdb-4.0.10 gitpython-3.1.29 grandalf-0.6 jmespath-0.10.0 mailchecker-5.0.7 markdown-it-py-2.1.0 mdurl-0.1.2 nanotime-0.5.2 networkx-2.6.3 opencv-python-headless-4.7.0.68 openpyxl-3.0.10 pathspec-0.9.0 phonenumbers-8.13.4 ply-3.11 protobuf-3.20.1 pydot-1.4.2 pygit2-1.10.1 pygtrie-2.5.0 python-benedict-0.26.0 python-fsutil-0.9.3 python-slugify-6.1.2 pytorch-lightning-1.8.5.post0 qudida-0.0.4 rich-13.2.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7 s3fs-2021.11.0 s3transfer-0.4.2 sagemaker-experiments-0.1.42 scikit-image-0.19.3 shortuuid-1.0.11 shtab-1.5.8 smmap-5.0.0 tabulate-0.9.0 tensorboardX-2.5.1 text-unidecode-1.3 tifffile-2021.11.2 voluptuous-0.13.1 wrapt-1.14.1 xlrd-2.0.1 xmltodict-0.13.0 zc.lockfile-2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker 2.93.0 requires boto3<2.0,>=1.20.21, but you have boto3 1.17.106 which is incompatible.
# docker-compose 1.29.2 requires PyYAML<6,>=3.10, but you have pyyaml 6.0 which is incompatible.
# awscli 1.27.44 requires botocore==1.29.44, but you have botocore 1.20.106 which is incompatible.
# awscli 1.27.44 requires PyYAML<5.5,>=3.10, but you have pyyaml 6.0 which is incompatible.
# awscli 1.27.44 requires s3transfer<0.7.0,>=0.6.0, but you have s3transfer 0.4.2 which is incompatible.

# %%
from typing import Any, Dict, Optional, Tuple

import os
import subprocess
import torch
import json
import tarfile

import pytorch_lightning as pl
import torchvision.transforms as T
import torch.nn.functional as F

from pathlib import Path
from torchvision.datasets import ImageFolder
from pytorch_lightning.plugins.environments import LightningEnvironment
from torch.utils.data import DataLoader, Dataset
from torchmetrics.functional import accuracy
from pytorch_lightning import loggers as pl_loggers
from datetime import datetime

from scripts.model import LitResnet
from scripts.dataset import IntelCapstoneDataModule

# %%
def eval_model(trainer, model, datamodule):
    test_res = trainer.test(model, datamodule)[0]
    
    report_dict = {
        "multiclass_classification_metrics": {
            "accuracy": {
                "value": test_res["test/acc"],
                "standard_deviation": "0",
            },
        },
    }
    
    eval_folder = Path("tmp")
    
    out_path = eval_folder / "evaluation.json"
    
    print(f":: Writing to {out_path.absolute()}")
    
    with out_path.open("w") as f:
        f.write(json.dumps(report_dict))

# %%
model_path = "tmp/model.tar.gz"
with tarfile.open(model_path) as tar:
    tar.extractall(path=".")

datamodule = IntelCapstoneDataModule(
    train_data_dir='test/',
    test_data_dir='test/',
    num_workers=os.cpu_count(),
    albumentations = '{}'
)
datamodule.setup()

model = LitResnet.load_from_checkpoint(checkpoint_path="last.ckpt")

trainer = pl.Trainer(
    accelerator="auto",
)

print(":: Evaluating Model")
eval_model(trainer, model, datamodule)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# :: Evaluating Model
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/acc          │    0.7053298950195312     │
# │         test/loss         │    0.7563663721084595     │
# └───────────────────────────┴───────────────────────────┘
# :: Writing to /home/ec2-user/SageMaker/sagemaker-pipeline/capstone/tmp/evaluation.json
